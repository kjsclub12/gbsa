# %% [markdown]
# # Multi-variable Linear_Regression

# %% [markdown]
# 실행을 위한 모듈 버전 변경

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %% [markdown]
# ## 1. INPUT : 2 ( X1, X2)

# %% [markdown]
# ### 전체 학습코드

# %%
import tensorflow as tf
import numpy as np

learning_rate = 0.01
training_cnt = 100
display_step = 10

train_X1 = np.array([1., 0., 3., 0., 5.])
train_X2 = np.array([0., 2., 0., 4., 0.])

train_Y = np.array([1., 2., 3., 4., 5.])

X1 = tf.placeholder("float")
X2 = tf.placeholder("float")
Y = tf.placeholder("float")

W1 = tf.Variable([.0], tf.float32, name = "weight1")
W2 = tf.Variable([.0], tf.float32, name = "weight2")
b = tf.Variable([.0], tf.float32, name = "bias")

pred = X1 * W1 + X2 * W2 + b

cost = tf.reduce_mean(tf.pow(pred-Y, 2))
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
op_train = optimizer.minimize(cost)

sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

for epoch in range(training_cnt):
    r_cost, r_W1, r_W2, r_b,r_pred, _ = sess.run([cost, W1, W2, b,pred, op_train], feed_dict = {X1: train_X1, X2: train_X2, Y: train_Y})

    if (epoch+1) % display_step == 0:
        print("Run_count : [%04d], Train_cost =[%.4f], W1 =[%.4f], W2 =[%.4f], b =[%.4f], pred =[%.4f %.4f %.4f %.4f %.4f]" 
              % (epoch+1, r_cost, r_W1, r_W2, r_b,r_pred[0],r_pred[1],r_pred[2],r_pred[3],r_pred[4] ))
                  
print("Optimization Finished!") 
print("Run_count : [%04d], Train_cost =[%.4f], W1 =[%.4f], W2 =[%.4f], b =[%.4f], pred =[%.4f %.4f %.4f %.4f %.4f]" 
              % (epoch+1, r_cost, r_W1, r_W2, r_b,r_pred[0],r_pred[1],r_pred[2],r_pred[3],r_pred[4] ))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Run_count : [0010], Train_cost =[1.0022], W1 =[0.7019], W2 =[0.4965], b =[0.3238], pred =[1.0257 1.3167 2.4296 2.3097 3.8335]
# Run_count : [0020], Train_cost =[0.1409], W1 =[0.8565], W2 =[0.7164], b =[0.4162], pred =[1.2726 1.8489 2.9856 3.2816 4.6986]
# Run_count : [0030], Train_cost =[0.0509], W1 =[0.8823], W2 =[0.8041], b =[0.4340], pred =[1.3163 2.0422 3.0809 3.6504 4.8454]
# Run_count : [0040], Train_cost =[0.0364], W1 =[0.8872], W2 =[0.8437], b =[0.4311], pred =[1.3183 2.1138 3.0927 3.7966 4.8671]
# Run_count : [0050], Train_cost =[0.0324], W1 =[0.8897], W2 =[0.8587], b =[0.4218], pred =[1.3115 2.1392 3.0910 3.8567 4.8704]
# Run_count : [0060], Train_cost =[0.0302], W1 =[0.8924], W2 =[0.8680], b =[0.4105], pred =[1.3029 2.1466 3.0877 3.8827 4.8726]
# Run_count : [0070], Train_cost =[0.0284], W1 =[0.8953], W2 =[0.8741], b =[0.3987], pred =[1.2940 2.1468 3.0847 3.8949 4.8754]
# Run_count : [0080], Train_cost =[0.0267], W1 =[0.8983], W2 =[0.8787], b =[0.3869], pred =[1.2853 2.1443 3.0820 3.9016 4.8787]
# Run_count : [0090], Train_cost =[0.0251], W1 =[0.9014], W2 =[0.8827], b =[0.3754], pred =[1.2767 2.1407 3.0794 3.9060 4.8821]
# Run_count : [0100], Train_cost =[0.0236], W1 =[0.9043], W2 =[0.8863], b =[0.3641], pred =[1.2684 2.1368 3.0770 3.9094 4.8856]
# Optimization Finished!
# Run_count : [0100], Train_cost =[0.0236], W1 =[0.9043], W2 =[0.8863], b =[0.3641], pred =[1.2684 2.1368 3.0770 3.9094 4.8856]

# %% [markdown]
# ### 1) 모델 구축(build graph)

# %%
import tensorflow as tf
import numpy as np

learning_rate = 0.01
training_cnt = 10
display_step = 1

train_X1 = np.array([1., 0., 3., 0., 5.])
train_X2 = np.array([0., 2., 0., 4., 0.])

train_Y = np.array([1., 2., 3., 4., 5.])

X1 = tf.placeholder("float")
X2 = tf.placeholder("float")
Y = tf.placeholder("float")

W1 = tf.Variable([.0], tf.float32, name = "weight1")
W2 = tf.Variable([.0], tf.float32, name = "weight2")
b = tf.Variable([.0], tf.float32, name = "bias")

pred = X1 * W1 + X2 * W2 + b

cost = tf.reduce_mean(tf.pow(pred-Y, 2))
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
op_train = optimizer.minimize(cost)

# %% [markdown]
# ### 2) 모델 실행 (run/update)

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

for epoch in range(training_cnt):
    r_cost, r_W1, r_W2, r_b,r_pred, _ = sess.run([cost, W1, W2, b,pred, op_train], feed_dict = {X1: train_X1, X2: train_X2, Y: train_Y})

    if (epoch+1) % display_step == 0:
        print("Run_count : [%04d], Train_cost =[%.4f], W1 =[%.4f], W2 =[%.4f], b =[%.4f], pred =[%.4f %.4f %.4f %.4f %.4f]" 
              % (epoch+1, r_cost, r_W1, r_W2, r_b,r_pred[0],r_pred[1],r_pred[2],r_pred[3],r_pred[4] ))
                  
print("Optimization Finished!") 
print("Run_count : [%04d], Train_cost =[%.4f], W1 =[%.4f], W2 =[%.4f], b =[%.4f], pred =[%.4f %.4f %.4f %.4f %.4f]" 
              % (epoch+1, r_cost, r_W1, r_W2, r_b,r_pred[0],r_pred[1],r_pred[2],r_pred[3],r_pred[4] ))
# Out:
# Run_count : [0001], Train_cost =[11.0000], W1 =[0.0000], W2 =[0.0000], b =[0.0000], pred =[0.0000 0.0000 0.0000 0.0000 0.0000]
# Run_count : [0002], Train_cost =[8.2482], W1 =[0.1400], W2 =[0.0800], b =[0.0600], pred =[0.2000 0.2200 0.4800 0.3800 0.7600]
# Run_count : [0003], Train_cost =[6.2131], W1 =[0.2582], W2 =[0.1522], b =[0.1118], pred =[0.3701 0.4162 0.8866 0.7205 1.4030]
# Run_count : [0004], Train_cost =[4.7033], W1 =[0.3581], W2 =[0.2173], b =[0.1567], pred =[0.5147 0.5913 1.2308 1.0259 1.9470]
# Run_count : [0005], Train_cost =[3.5794], W1 =[0.4423], W2 =[0.2762], b =[0.1954], pred =[0.6377 0.7477 1.5223 1.3001 2.4069]
# Run_count : [0006], Train_cost =[2.7396], W1 =[0.5133], W2 =[0.3294], b =[0.2290], pred =[0.7423 0.8877 1.7690 1.5465 2.7956]
# Run_count : [0007], Train_cost =[2.1096], W1 =[0.5732], W2 =[0.3775], b =[0.2580], pred =[0.8312 1.0131 1.9777 1.7681 3.1241]
# Run_count : [0008], Train_cost =[1.6348], W1 =[0.6237], W2 =[0.4211], b =[0.2831], pred =[0.9068 1.1254 2.1542 1.9677 3.4016]
# Run_count : [0009], Train_cost =[1.2755], W1 =[0.6662], W2 =[0.4607], b =[0.3049], pred =[0.9711 1.2262 2.3034 2.1475 3.6358]
# Run_count : [0010], Train_cost =[1.0022], W1 =[0.7019], W2 =[0.4965], b =[0.3238], pred =[1.0257 1.3167 2.4296 2.3097 3.8335]
# Optimization Finished!
# Run_count : [0010], Train_cost =[1.0022], W1 =[0.7019], W2 =[0.4965], b =[0.3238], pred =[1.0257 1.3167 2.4296 2.3097 3.8335]

# %% [markdown]
# ### 1) 모델 구축(build graph)
# #### 트레이닝 데이터 변수 선언
# - 입력으로 들어가는 x1, x2 즉 두개의 변수 선언
# - 출력은 하나 Y data

# %%
train_X1 = np.array([1., 0., 3., 0., 5.])
train_X2 = np.array([0., 2., 0., 4., 0.])

train_Y = np.array([1., 2., 3., 4., 5.])

# %% [markdown]
# #### tf graph input
# - linear_regression model과 같다. 단지 입력변수를 담는 placeholter가 2개로 늘어났다

# %%
X1 = tf.placeholder("float")
X2 = tf.placeholder("float")
Y = tf.placeholder("float")

# %% [markdown]
# #### set model weight
# - 입력변수가 2개이기 때문에 weight도 2개로 늘어난다.

# %%
W1 = tf.Variable([.0], tf.float32, name = "weight1")
W2 = tf.Variable([.0], tf.float32, name = "weight2")
b = tf.Variable([.0], tf.float32, name = "bias")

# %% [markdown]
# #### linear model(예측 값 구현)

# %% [markdown]
# $$H(x_1,x_2)=x_1w_1+x_2w_2+b$$

# %%
pred = X1 * W1 + X2 * W2 + b

# %% [markdown]
# #### cost/loss function 구현

# %% [markdown]
# $$cost(W,b)=\frac 1m\sum_{i=1}^m(H(x_1^{(i)},x_2^{(i)})-y^{(i)})^2$$

# %%
cost = tf.reduce_mean(tf.pow(pred-Y, 2))

# %% [markdown]
# #### 학습 --> cost 최소화
# - gradientdecent 함수 사용(경사 하강법)

# %%
cost = tf.reduce_mean(tf.pow(pred-Y, 2))
optimizer = tf.train.GradientDescentOptimizer(learning_rate) # 하이퍼파라미터에서 설정한 값
op_train = optimizer.minimize(cost) # optimizer에서 나온값을 최소하 시키도록 학습

# %% [markdown]
# ### 2) 모델 실행 (run/update)

# %%
# 세션오픈
sess = tf.Session()
# 변수들에 초기값 할당
init = tf.global_variables_initializer()
sess.run(init)

# %%
for epoch in range(training_cnt): # traing_cnt 횟수만큼 반복 실행
    r_cost, r_W1, r_W2, r_b,r_pred, _ = sess.run([cost, W1, W2, b,pred, op_train], feed_dict = {X1: train_X1, X2: train_X2, Y: train_Y})
    #sess.run을통해 학습한(변경된) cost, W, b 값을 r_cost, r_W, r_b 에 update
    if (epoch+1) % display_step == 0:
        print("Run_count : [%04d], Train_cost =[%.4f], W1 =[%.4f], W2 =[%.4f], b =[%.4f], pred =[%.4f %.4f %.4f %.4f %.4f]" 
              % (epoch+1, r_cost, r_W1, r_W2, r_b,r_pred[0],r_pred[1],r_pred[2],r_pred[3],r_pred[4] ))
        # sess.run을 통해 학습된 값 출력(pred의 경우 value가 5개가 나오기 때문에 그 값을 소수점4번째까지만 나타내려 각각 print함 )
        
print("Optimization Finished!") 
print("Run_count : [%04d], Train_cost =[%.4f], W1 =[%.4f], W2 =[%.4f], b =[%.4f], pred =[%.4f %.4f %.4f %.4f %.4f]" 
              % (epoch+1, r_cost, r_W1, r_W2, r_b,r_pred[0],r_pred[1],r_pred[2],r_pred[3],r_pred[4] ))
# Out:
# Run_count : [0001], Train_cost =[11.0000], W1 =[0.0000], W2 =[0.0000], b =[0.0000], pred =[0.0000 0.0000 0.0000 0.0000 0.0000]
# Run_count : [0002], Train_cost =[8.2482], W1 =[0.1400], W2 =[0.0800], b =[0.0600], pred =[0.2000 0.2200 0.4800 0.3800 0.7600]
# Run_count : [0003], Train_cost =[6.2131], W1 =[0.2582], W2 =[0.1522], b =[0.1118], pred =[0.3701 0.4162 0.8866 0.7205 1.4030]
# Run_count : [0004], Train_cost =[4.7033], W1 =[0.3581], W2 =[0.2173], b =[0.1567], pred =[0.5147 0.5913 1.2308 1.0259 1.9470]
# Run_count : [0005], Train_cost =[3.5794], W1 =[0.4423], W2 =[0.2762], b =[0.1954], pred =[0.6377 0.7477 1.5223 1.3001 2.4069]
# Run_count : [0006], Train_cost =[2.7396], W1 =[0.5133], W2 =[0.3294], b =[0.2290], pred =[0.7423 0.8877 1.7690 1.5465 2.7956]
# Run_count : [0007], Train_cost =[2.1096], W1 =[0.5732], W2 =[0.3775], b =[0.2580], pred =[0.8312 1.0131 1.9777 1.7681 3.1241]
# Run_count : [0008], Train_cost =[1.6348], W1 =[0.6237], W2 =[0.4211], b =[0.2831], pred =[0.9068 1.1254 2.1542 1.9677 3.4016]
# Run_count : [0009], Train_cost =[1.2755], W1 =[0.6662], W2 =[0.4607], b =[0.3049], pred =[0.9711 1.2262 2.3034 2.1475 3.6358]
# Run_count : [0010], Train_cost =[1.0022], W1 =[0.7019], W2 =[0.4965], b =[0.3238], pred =[1.0257 1.3167 2.4296 2.3097 3.8335]
# Optimization Finished!
# Run_count : [0010], Train_cost =[1.0022], W1 =[0.7019], W2 =[0.4965], b =[0.3238], pred =[1.0257 1.3167 2.4296 2.3097 3.8335]

# %% [markdown]
# ### 3)  def(함수 만들기)
# - build graph, run graph 함수 생성

# %%
import tensorflow as tf
import numpy as np

learning_rate = 0.01
training_cnt = 10
display_step = 1

train_X1 = np.array([1., 0., 3., 0., 5.])
train_X2 = np.array([0., 2., 0., 4., 0.])

train_Y = np.array([1., 2., 3., 4., 5.])

def make_graph() :
    global X1, X2, Y, W1, W2, b, pred ,cost,optimizer, op_train

    X1 = tf.placeholder("float")
    X2 = tf.placeholder("float")
    Y = tf.placeholder("float")

    W1 = tf.Variable([.0], tf.float32, name = "weight1")
    W2 = tf.Variable([.0], tf.float32, name = "weight2")
    b = tf.Variable([.0], tf.float32, name = "bias")

    pred = X1 * W1 + X2 * W2 + b

    cost = tf.reduce_mean(tf.pow(pred-Y, 2))
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    op_train = optimizer.minimize(cost)

def run_graph() :    

    sess = tf.Session()
    init = tf.global_variables_initializer()
    sess.run(init)
    
    for epoch in range(training_cnt):
        r_cost, r_W1, r_W2, r_b,r_pred, _ = sess.run([cost, W1, W2, b,pred, op_train], feed_dict = {X1: train_X1, X2: train_X2, Y: train_Y})

        if (epoch+1) % display_step == 0:
            print("Run_count : [%04d], Train_cost =[%.4f], W1 =[%.4f], W2 =[%.4f], b =[%.4f], pred =[%.4f %.4f %.4f %.4f %.4f]" 
                  % (epoch+1, r_cost, r_W1, r_W2, r_b,r_pred[0],r_pred[1],r_pred[2],r_pred[3],r_pred[4] ))
                  
    print("Optimization Finished!") 
    print("Run_count : [%04d], Train_cost =[%.4f], W1 =[%.4f], W2 =[%.4f], b =[%.4f], pred =[%.4f %.4f %.4f %.4f %.4f]" 
              % (epoch+1, r_cost, r_W1, r_W2, r_b,r_pred[0],r_pred[1],r_pred[2],r_pred[3],r_pred[4] ))

# %%
make_graph()

# %%
run_graph()
# Out:
# Run_count : [0001], Train_cost =[11.0000], W1 =[0.0000], W2 =[0.0000], b =[0.0000], pred =[0.0000 0.0000 0.0000 0.0000 0.0000]
# Run_count : [0002], Train_cost =[8.2482], W1 =[0.1400], W2 =[0.0800], b =[0.0600], pred =[0.2000 0.2200 0.4800 0.3800 0.7600]
# Run_count : [0003], Train_cost =[6.2131], W1 =[0.2582], W2 =[0.1522], b =[0.1118], pred =[0.3701 0.4162 0.8866 0.7205 1.4030]
# Run_count : [0004], Train_cost =[4.7033], W1 =[0.3581], W2 =[0.2173], b =[0.1567], pred =[0.5147 0.5913 1.2308 1.0259 1.9470]
# Run_count : [0005], Train_cost =[3.5794], W1 =[0.4423], W2 =[0.2762], b =[0.1954], pred =[0.6377 0.7477 1.5223 1.3001 2.4069]
# Run_count : [0006], Train_cost =[2.7396], W1 =[0.5133], W2 =[0.3294], b =[0.2290], pred =[0.7423 0.8877 1.7690 1.5465 2.7956]
# Run_count : [0007], Train_cost =[2.1096], W1 =[0.5732], W2 =[0.3775], b =[0.2580], pred =[0.8312 1.0131 1.9777 1.7681 3.1241]
# Run_count : [0008], Train_cost =[1.6348], W1 =[0.6237], W2 =[0.4211], b =[0.2831], pred =[0.9068 1.1254 2.1542 1.9677 3.4016]
# Run_count : [0009], Train_cost =[1.2755], W1 =[0.6662], W2 =[0.4607], b =[0.3049], pred =[0.9711 1.2262 2.3034 2.1475 3.6358]
# Run_count : [0010], Train_cost =[1.0022], W1 =[0.7019], W2 =[0.4965], b =[0.3238], pred =[1.0257 1.3167 2.4296 2.3097 3.8335]
# Optimization Finished!
# Run_count : [0010], Train_cost =[1.0022], W1 =[0.7019], W2 =[0.4965], b =[0.3238], pred =[1.0257 1.3167 2.4296 2.3097 3.8335]

# %% [markdown]
# ## 2. INPUT : 2 ( matrix 이용)

# %%
import tensorflow as tf
import numpy as np

learning_rate = 0.01
training_cnt = 10
display_step = 1

train_MX = np.array([[1., 0.], [0., 2.], [3., 0.], [0., 4.], [5., 0.] ])
train_Y = np.array([[1.], [2.], [3.], [4.], [5.]])

MX = tf.placeholder("float",shape=[None, 2])
Y = tf.placeholder("float", shape=[None, 1])

W = tf.Variable(tf.zeros([2, 1]), name='weight')
b = tf.Variable(tf.zeros([1]), name='bias')

pred = tf.matmul(MX ,W) + b

cost = tf.reduce_mean(tf.pow(pred-Y, 2))
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
op_train = optimizer.minimize(cost)

sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

for epoch in range(training_cnt):
    r_cost, r_W, r_b, r_pred, _ = sess.run([cost, W, b, pred, op_train], feed_dict = {MX: train_MX, Y: train_Y})
    
    if (epoch+1) % display_step == 0:
        print("Run_count : [%04d], Train_cost =[%.4f], W =[%.4f %.4f], b =[%.4f], pred =[%.4f %.4f %.4f %.4f %.4f]" 
              % (epoch+1, r_cost, r_W[0], r_W[1], r_b, r_pred[0],r_pred[1],r_pred[2],r_pred[3],r_pred[4] ))
        
                   
print("Optimization Finished!") 
print("Run_count : [%04d], Train_cost =[%.4f], W =[%.4f %.4f], b =[%.4f], pred =[%.4f %.4f %.4f %.4f %.4f]" 
              % (epoch+1, r_cost, r_W[0], r_W[1], r_b, r_pred[0],r_pred[1],r_pred[2],r_pred[3],r_pred[4] ))
# Out:
# Run_count : [0001], Train_cost =[11.0000], W =[0.0000 0.0000], b =[0.0000], pred =[0.0000 0.0000 0.0000 0.0000 0.0000]
# Run_count : [0002], Train_cost =[8.2482], W =[0.1400 0.0800], b =[0.0600], pred =[0.2000 0.2200 0.4800 0.3800 0.7600]
# Run_count : [0003], Train_cost =[6.2131], W =[0.2582 0.1522], b =[0.1118], pred =[0.3701 0.4162 0.8866 0.7205 1.4030]
# Run_count : [0004], Train_cost =[4.7033], W =[0.3581 0.2173], b =[0.1567], pred =[0.5147 0.5913 1.2308 1.0259 1.9470]
# Run_count : [0005], Train_cost =[3.5794], W =[0.4423 0.2762], b =[0.1954], pred =[0.6377 0.7477 1.5223 1.3001 2.4069]
# Run_count : [0006], Train_cost =[2.7396], W =[0.5133 0.3294], b =[0.2290], pred =[0.7423 0.8877 1.7690 1.5465 2.7956]
# Run_count : [0007], Train_cost =[2.1096], W =[0.5732 0.3775], b =[0.2580], pred =[0.8312 1.0131 1.9777 1.7681 3.1241]
# Run_count : [0008], Train_cost =[1.6348], W =[0.6237 0.4211], b =[0.2831], pred =[0.9068 1.1254 2.1542 1.9677 3.4016]
# Run_count : [0009], Train_cost =[1.2755], W =[0.6662 0.4607], b =[0.3049], pred =[0.9711 1.2262 2.3034 2.1475 3.6358]
# Run_count : [0010], Train_cost =[1.0022], W =[0.7019 0.4965], b =[0.3238], pred =[1.0257 1.3167 2.4296 2.3097 3.8335]
# Optimization Finished!
# Run_count : [0010], Train_cost =[1.0022], W =[0.7019 0.4965], b =[0.3238], pred =[1.0257 1.3167 2.4296 2.3097 3.8335]

# %% [markdown]
# #### matrix를 이용한 구축

# %% [markdown]
# $$H(x_1,x_2)=x_1w_1+x_2w_2+b$$

# %% [markdown]
# $$( x_1 \  \ x_2) * {w_1 \choose w_2} = ( x_1w_1 + x_2w_2)$$

# %%
train_MX = np.array([[1., 0.], [0., 2.], [3., 0.], [0., 4.], [5., 0.] ])
  # 5 by 2 matrix
train_Y = np.array([[1.], [2.], [3.], [4.], [5.]])
  # 5 by 1 matrix
MX = tf.placeholder("float",shape=[None, 2])  #들어오는 row는 정해진게 없고, column 은 2개 즉 변수 2개
Y = tf.placeholder("float", shape=[None, 1])  

W = tf.Variable(tf.zeros([2, 1]), name='weight')  #MX의 두개의 변수와 연결이 되기때문에 row는 2개 출력 값은 Y와 같은 shape여야 하므로 하나
b = tf.Variable(tf.zeros([1]), name='bias')

pred = tf.matmul(MX ,W) + b
